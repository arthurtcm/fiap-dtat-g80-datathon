# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
def filter_columns(df, filters: list): # adiciono no array o padrão que existe nas colunas e que não quero que tenha na saída final
    selected_columns = [True] * len(df.columns)  # Inicializa todas as colunas como True
    for index, column in enumerate(df.columns):
        if any(filter in column for filter in filters): selected_columns[index] = False
    return df[df.columns[selected_columns]]

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
base = pd.read_csv('dados/PEDE_PASSOS_DATASET_FIAP.csv', sep =';')

# %%
base.head()
# Out:
#   INSTITUICAO_ENSINO_ALUNO_2020     NOME IDADE_ALUNO_2020 ANOS_PM_2020  \
# 0                Escola Pública  ALUNO-1               11            2
# 1                           NaN  ALUNO-2              NaN          NaN
# 2                Escola Pública  ALUNO-3               12            2
# 3                Escola Pública  ALUNO-4               10            2
# 4                Escola Pública  ALUNO-5               10            1
#
#   FASE_TURMA_2020 PONTO_VIRADA_2020          INDE_2020 INDE_CONCEITO_2020  \
# 0              2H               Não           7.883752                  B
# 1             NaN               NaN                NaN                NaN
# 2              3H               Não  7.856389666666666                  B
# 3              1D               Não           5.076252                  D
# 4              2M               Não           8.077085                  B
#
#   PEDRA_2020                                  DESTAQUE_IEG_2020  \
# ...

# %%
base = base.dropna(subset=base.columns.difference(['NOME']), how='all')

# %% [markdown]
# # Base 22

# %%
base_22 = filter_columns(base, ['2021', '2020'])
base_22.head()
# Out:
#       NOME  FASE_2022 TURMA_2022  ANO_INGRESSO_2022 BOLSISTA_2022  INDE_2022  \
# 0  ALUNO-1        NaN        NaN                NaN           NaN        NaN
# 1  ALUNO-2        0.0          K             2022.0           Não   7.675509
# 2  ALUNO-3        NaN        NaN                NaN           NaN        NaN
# 3  ALUNO-4        2.0          J             2022.0           Não   7.117065
# 4  ALUNO-5        2.0          L             2019.0           Não   7.232336
#
#    CG_2022  CF_2022  CT_2022 PEDRA_2022  \
# 0      NaN      NaN      NaN        NaN
# 1    245.0     66.0      6.0   Ametista
# 2      NaN      NaN      NaN        NaN
# 3    451.0     69.0      3.0   Ametista
# 4    415.0     61.0     12.0   Ametista
#
#                                  DESTAQUE_IEG_2022  \
# 0                                              NaN
# 1  Destaque: A sua boa entrega das lições de casa.
# 2                                              NaN
# ...

# %%
base_22 = base_22.drop(['DESTAQUE_IEG_2022', 'DESTAQUE_IDA_2022', 'DESTAQUE_IPV_2022'], axis=1)
base_22.head()
# Out:
#       NOME  FASE_2022 TURMA_2022  ANO_INGRESSO_2022 BOLSISTA_2022  INDE_2022  \
# 0  ALUNO-1        NaN        NaN                NaN           NaN        NaN
# 1  ALUNO-2        0.0          K             2022.0           Não   7.675509
# 2  ALUNO-3        NaN        NaN                NaN           NaN        NaN
# 3  ALUNO-4        2.0          J             2022.0           Não   7.117065
# 4  ALUNO-5        2.0          L             2019.0           Não   7.232336
#
#    CG_2022  CF_2022  CT_2022 PEDRA_2022  IAA_2022  IEG_2022  IPS_2022  \
# 0      NaN      NaN      NaN        NaN       NaN       NaN       NaN
# 1    245.0     66.0      6.0   Ametista  10.00002  7.581705       7.5
# 2      NaN      NaN      NaN        NaN       NaN       NaN       NaN
# 3    451.0     69.0      3.0   Ametista  10.00002  8.071429       7.5
# 4    415.0     61.0     12.0   Ametista   6.41668  8.557505       7.5
#
#    IDA_2022  NOTA_PORT_2022  NOTA_MAT_2022  NOTA_ING_2022  QTD_AVAL_2022  \
# ...

# %%
base_22 = base_22.dropna(subset=base_22.columns.difference(['NOME']), how='all')
base_22.head()
# Out:
#       NOME  FASE_2022 TURMA_2022  ANO_INGRESSO_2022 BOLSISTA_2022  INDE_2022  \
# 1  ALUNO-2        0.0          K             2022.0           Não   7.675509
# 3  ALUNO-4        2.0          J             2022.0           Não   7.117065
# 4  ALUNO-5        2.0          L             2019.0           Não   7.232336
# 5  ALUNO-6        2.0          K             2022.0           Não   7.741669
# 6  ALUNO-7        1.0          U             2022.0           Não   7.406743
#
#    CG_2022  CF_2022  CT_2022 PEDRA_2022  IAA_2022  IEG_2022  IPS_2022  \
# 1    245.0     66.0      6.0   Ametista  10.00002  7.581705       7.5
# 3    451.0     69.0      3.0   Ametista  10.00002  8.071429       7.5
# 4    415.0     61.0     12.0   Ametista   6.41668  8.557505       7.5
# 5    221.0     35.0      2.0   Ametista   9.00002  9.333333       7.5
# 6    357.0     93.0      7.0   Ametista  10.00002  9.314954       7.5
#
#    IDA_2022  NOTA_PORT_2022  NOTA_MAT_2022  NOTA_ING_2022  QTD_AVAL_2022  \
# ...

# %%
base_22['NIVEL_IDEAL_2022'].unique()
# Out:
# array(['Fase 2 (5º e 6º ano)', 'Fase 3 (7º e 8º ano)', 'Fase 6 (2º EM)',
#        'ALFA  (2º e 3º ano)', 'Fase 1 (4º ano)', 'Fase 4 (9º ano)',
#        'Fase 8 (Universitários)', 'Fase 5 (1º EM)', 'Fase 7 (3º EM)'],
#       dtype=object)

# %%
fases = ['ALFA  (2º e 3º ano)', 'Fase 1 (4º ano)', 'Fase 2 (5º e 6º ano)', 'Fase 3 (7º e 8º ano)', 'Fase 4 (9º ano)', 'Fase 5 (1º EM)', 'Fase 6 (2º EM)', 'Fase 7 (3º EM)', 'Fase 8 (Universitários)']
valores = [0, 1, 2, 3, 4, 5, 6, 7, 8]

mapeamento = dict(zip(fases, valores))

base_22['NIVEL_IDEAL_2022_NUM'] = base_22['NIVEL_IDEAL_2022'].map(mapeamento)
base_22['NIVEL_IDEAL_2022_NUM'].unique()
# Out:
# array([2, 3, 6, 0, 1, 4, 8, 5, 7], dtype=int64)

# %%
base_22.to_csv('base_2022.csv')

# %% [markdown]
# # Base 2021

# %%
base_21 = filter_columns(base, ['2022', '2020'])
base_21 = base_21.dropna(subset=base_21.columns.difference(['NOME']), how='all')
base_21.head()
# Out:
#         NOME  FASE_2021 TURMA_2021 INSTITUICAO_ENSINO_ALUNO_2021  \
# 0    ALUNO-1        2.0          G                  Rede Decisão
# 2    ALUNO-3        3.0          F                Escola Pública
# 4    ALUNO-5        2.0          L                Escola Pública
# 7    ALUNO-8        5.0          L                  Rede Decisão
# 10  ALUNO-11        1.0          A                  Rede Decisão
#
#    SINALIZADOR_INGRESSANTE_2021 PEDRA_2021 INDE_2021  IAA_2021  IEG_2021  \
# 0                   Ingressante   Ametista     7.319       7.5       6.3
# 2                      Veterano   Ametista     7.021       7.1       6.9
# 4                      Veterano   Ametista     7.399       7.4       7.5
# 7                      Veterano    Topázio     8.269       8.8       8.6
# 10                     Veterano    Topázio     8.990       9.0      10.0
#
#     IPS_2021  IDA_2021  IPP_2021          REC_EQUIPE_1_2021  \
# 0        6.9       8.8       7.7          Promovido de Fase
# ...

# %%
base_21['NIVEL_IDEAL_2021'].unique()
# Out:
# array(['Nível 3 (7o e 8o ano)', 'Nível 2 (5o e 6o ano)',
#        'Nível 5 (1o EM)', 'Nível 1 (4o ano)', 'Nível 4 (9o ano)',
#        'Nível 8 (Universitários)', 'Nível 6 (2o EM)',
#        'ALFA  (2o e 3o ano)', 'Nível 7 (3o EM)', 'ERRO'], dtype=object)

# %%
(base_21['NIVEL_IDEAL_2021'] == 'ERRO').sum()
# Out:
# 2

# %%
fases = ['ALFA  (2o e 3o ano)', 'Nível 1 (4o ano)', 'Nível 2 (5o e 6o ano)', 'Nível 3 (7o e 8o ano)', 'Nível 4 (9o ano)', 'Nível 5 (1o EM)', 'Nível 6 (2o EM)', 'Nível 7 (3o EM)', 'Nível 8 (Universitários)', 'ERRO']
valores = [0, 1, 2, 3, 4, 5, 6, 7, 8, -1]

mapeamento = dict(zip(fases, valores))

base_21['NIVEL_IDEAL_2021_NUM'] = base_21['NIVEL_IDEAL_2021'].map(mapeamento)
base_21['NIVEL_IDEAL_2021_NUM'].unique()
# Out:
# array([ 3,  2,  5,  1,  4,  8,  6,  0,  7, -1], dtype=int64)

# %%
base_21.to_csv('base_2021.csv')

# %% [markdown]
# # Base 2020

# %%
base_20 = filter_columns(base, ['2022', '2021'])
base_20 = base_20.dropna(subset=base_20.columns.difference(['NOME']), how='all')
base_20.head()
# Out:
#   INSTITUICAO_ENSINO_ALUNO_2020     NOME IDADE_ALUNO_2020 ANOS_PM_2020  \
# 0                Escola Pública  ALUNO-1               11            2
# 2                Escola Pública  ALUNO-3               12            2
# 3                Escola Pública  ALUNO-4               10            2
# 4                Escola Pública  ALUNO-5               10            1
# 7            Rede Decisão/União  ALUNO-8               14            3
#
#   FASE_TURMA_2020 PONTO_VIRADA_2020          INDE_2020 INDE_CONCEITO_2020  \
# 0              2H               Não           7.883752                  B
# 2              3H               Não  7.856389666666666                  B
# 3              1D               Não           5.076252                  D
# 4              2M               Não           8.077085                  B
# 7              4L               Sim  8.381390666666666                  B
#
#   PEDRA_2020                                  DESTAQUE_IEG_2020  \
# ...

# %%
base_20['FASE_TURMA_2020'].unique()
# Out:
# array(['2H', '3H', '1D', '2M', '4L', '3B', '0A', '3G', '2D', '1G', '3E',
#        '3J', '0C', '2C', '7B', '3C', '2N', '3F', '4F', '1M', '0D', '2F',
#        '5X', '6C', '6B', '5F', '1N', '2L', '1F', '3L', '0B', '1A', '4B',
#        '6A', '0G', '3M', '3A', '7A', '1J', '0F', '0H', '4A', '1C', '5A',
#        '5L', '1R', '2J', '1H', '8A', '1B', '0E', '5G', '2G', '2R', '5B',
#        '2P', '1E', '2B', '2E', '3R', '1K', '4E', 'D207'], dtype=object)

# %%
base_20.loc[base_20['FASE_TURMA_2020']=='D207']
# Out:
#      INSTITUICAO_ENSINO_ALUNO_2020        NOME IDADE_ALUNO_2020 ANOS_PM_2020  \
# 1258                          V202  ALUNO-1259             D108         D971
#
#      FASE_TURMA_2020 PONTO_VIRADA_2020 INDE_2020 INDE_CONCEITO_2020  \
# 1258            D207             D9600      D980            D9891/2
#
#      PEDRA_2020 DESTAQUE_IEG_2020 DESTAQUE_IDA_2020 DESTAQUE_IPV_2020  \
# 1258   D9891/2A              D301              D302               NaN
#
#      IAA_2020 IEG_2020 IPS_2020 IDA_2020 IPP_2020 IPV_2020 IAN_2020 FASE_2020  \
# 1258     D910     V920     D930     D940     D950     D960     D970         2
#
#      TURMA_2020
# 1258          D

# %%
base_20['FASE_2020'] = base_20['FASE_TURMA_2020'].str[0]
base_20['TURMA_2020'] = base_20['FASE_TURMA_2020'].str[1]
base_20.head()
# Out:
#   INSTITUICAO_ENSINO_ALUNO_2020     NOME IDADE_ALUNO_2020 ANOS_PM_2020  \
# 0                Escola Pública  ALUNO-1               11            2
# 2                Escola Pública  ALUNO-3               12            2
# 3                Escola Pública  ALUNO-4               10            2
# 4                Escola Pública  ALUNO-5               10            1
# 7            Rede Decisão/União  ALUNO-8               14            3
#
#   FASE_TURMA_2020 PONTO_VIRADA_2020          INDE_2020 INDE_CONCEITO_2020  \
# 0              2H               Não           7.883752                  B
# 2              3H               Não  7.856389666666666                  B
# 3              1D               Não           5.076252                  D
# 4              2M               Não           8.077085                  B
# 7              4L               Sim  8.381390666666666                  B
#
#   PEDRA_2020                                  DESTAQUE_IEG_2020  \
# ...

# %%
base_20.loc[base_20['NOME'] == 'ALUNO-1259', 'FASE_2020'] = '2'
base_20.loc[base_20['NOME'] == 'ALUNO-1259', 'TURMA_2020'] = 'D'

# %%
base_20.to_csv('base_2020.csv')
